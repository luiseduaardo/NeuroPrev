# %%
import pandas as pd
df = pd.read_csv('healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info() #tipo de cada coluna e verificação de valores nulos
df.describe() #estatísticas básicas
df.isnull().sum() #verifica contagem de valores nulos por coluna
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df = df.drop('id', axis = 1) #remove coluna id
df['bmi'] = df['bmi'].fillna(df['bmi'].median()) #preenche valores vazios de bmi com mediana
df = pd.get_dummies(df, columns = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status'])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             5110 non-null   float64
#  1   hypertension                    5110 non-null   int64
#  2   heart_disease                   5110 non-null   int64
#  3   avg_glucose_level               5110 non-null   float64
#  4   bmi                             5110 non-null   float64
#  5   stroke                          5110 non-null   int64
#  6   gender_Female                   5110 non-null   bool
#  7   gender_Male                     5110 non-null   bool
#  8   gender_Other                    5110 non-null   bool
#  9   ever_married_No                 5110 non-null   bool
#  10  ever_married_Yes                5110 non-null   bool
#  11  work_type_Govt_job              5110 non-null   bool
#  12  work_type_Never_worked          5110 non-null   bool
#  13  work_type_Private               5110 non-null   bool
#  14  work_type_Self-employed         5110 non-null   bool
#  15  work_type_children              5110 non-null   bool
#  16  Residence_type_Rural            5110 non-null   bool
#  17  Residence_type_Urban            5110 non-null   bool
#  18  smoking_status_Unknown          5110 non-null   bool
#  19  smoking_status_formerly smoked  5110 non-null   bool
#  20  smoking_status_never smoked     5110 non-null   bool
#  21  smoking_status_smokes           5110 non-null   bool
# dtypes: bool(16), float64(3), int64(3)
# memory usage: 319.5 KB
#     age  hypertension  heart_disease  avg_glucose_level   bmi  stroke  \
# 0  67.0             0              1             228.69  36.6       1
# 1  61.0             0              0             202.21  28.1       1
# 2  80.0             0              1             105.92  32.5       1
# 3  49.0             0              0             171.23  34.4       1
# 4  79.0             1              0             174.12  24.0       1
#
#    gender_Female  gender_Male  gender_Other  ever_married_No  ...  \
# 0          False         True         False            False  ...
# 1           True        False         False            False  ...
# 2          False         True         False            False  ...
# 3           True        False         False            False  ...
# 4           True        False         False            False  ...
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                   False               True                    False
# 1                   False              False                     True
# 2                   False               True                    False
# 3                   False               True                    False
# 4                   False              False                     True
#
#    work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 0               False                 False                  True
# 1               False                  True                 False
# 2               False                  True                 False
# 3               False                 False                  True
# 4               False                  True                 False
#
#    smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                   False                            True
# 1                   False                           False
# 2                   False                           False
# 3                   False                           False
# 4                   False                           False
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                        False                  False
# 1                         True                  False
# 2                         True                  False
# 3                        False                   True
# 4                         True                  False
#
# [5 rows x 22 columns]

# %%
bool_cols = df.select_dtypes(include = ['bool']).columns #identifica as colunas bool
df[bool_cols] = df[bool_cols].astype(int) #converte bool pra int
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             5110 non-null   float64
#  1   hypertension                    5110 non-null   int64
#  2   heart_disease                   5110 non-null   int64
#  3   avg_glucose_level               5110 non-null   float64
#  4   bmi                             5110 non-null   float64
#  5   stroke                          5110 non-null   int64
#  6   gender_Female                   5110 non-null   int64
#  7   gender_Male                     5110 non-null   int64
#  8   gender_Other                    5110 non-null   int64
#  9   ever_married_No                 5110 non-null   int64
#  10  ever_married_Yes                5110 non-null   int64
#  11  work_type_Govt_job              5110 non-null   int64
#  12  work_type_Never_worked          5110 non-null   int64
#  13  work_type_Private               5110 non-null   int64
#  14  work_type_Self-employed         5110 non-null   int64
#  15  work_type_children              5110 non-null   int64
#  16  Residence_type_Rural            5110 non-null   int64
#  17  Residence_type_Urban            5110 non-null   int64
#  18  smoking_status_Unknown          5110 non-null   int64
#  19  smoking_status_formerly smoked  5110 non-null   int64
#  20  smoking_status_never smoked     5110 non-null   int64
#  21  smoking_status_smokes           5110 non-null   int64
# dtypes: float64(3), int64(19)
# memory usage: 878.4 KB

# %%
from sklearn.model_selection import train_test_split
x = df.drop('stroke', axis = 1) #matriz de caracteristicas
y = df['stroke'] #resultado
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state = 6) #separa 80% dos dados para treino e 20% para teste
print(f"Pacientes no treino: {x_treino.shape[0]}")
print(f"Pacientes no teste: {x_teste.shape[0]}")
# Out:
# Pacientes no treino: 4088
# Pacientes no teste: 1022

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
modelo = DecisionTreeClassifier(random_state = 6, class_weight = 'balanced') #cria o modelo
modelo.fit(x_treino, y_treino) #treina o modelo
previsoes = modelo.predict(x_teste) #testa o modelo
print("Acerto:", accuracy_score(y_teste, previsoes))
print("\nRelatório Detalhado:\n", classification_report(y_teste, previsoes))
# Out:
# Acerto: 0.9207436399217221
#
# Relatório Detalhado:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       971
#            1       0.16      0.14      0.15        51
#
#     accuracy                           0.92      1022
#    macro avg       0.56      0.55      0.55      1022
# weighted avg       0.92      0.92      0.92      1022

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\roniv\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\roniv\anaconda3\lib\site-packages (from imbalanced-learn) (2.3.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\roniv\anaconda3\lib\site-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\roniv\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\roniv\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\roniv\anaconda3\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
from imblearn.over_sampling import SMOTENC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

#identificar categorias
categorias = []
for i, col in enumerate(x_treino.columns):
    if x_treino[col].nunique() <= 2: #se a coluna for binaria ou for int
        categorias.append(i)

smotenc = SMOTENC(categorical_features = categorias, random_state = 6) #não quebra os valores de categorias
x_treino_blc, y_treino_blc = smotenc.fit_resample(x_treino, y_treino)

#verificação
print(f"Antes: {y_treino.value_counts().to_dict()}")
print(f"Depois: {y_treino_blc.value_counts().to_dict()}")

modelo_rf = RandomForestClassifier(n_estimators = 100, class_weight = 'balanced', random_state = 6) #cria floresta com 100 árvores
modelo_rf.fit(x_treino_blc, y_treino_blc) #treina a floresta
previsoes_rf = modelo_rf.predict(x_teste) #testa os dados originais

probabilidades = modelo_rf.predict_proba(x_teste)
chance_avc = probabilidades[:, 1] #pega a coluna 1
limiar = 0.09 #novo limite
novas_previsoes = (chance_avc >= limiar).astype(int)

print("Acurácia:", accuracy_score(y_teste, novas_previsoes)) 
print("\nRelatório:\n", classification_report(y_teste, novas_previsoes))
# Out:
# Antes: {0: 3890, 1: 198}
# Depois: {0: 3890, 1: 3890}
# Acurácia: 0.662426614481409
#
# Relatório:
#                precision    recall  f1-score   support
#
#            0       0.99      0.65      0.79       971
#            1       0.12      0.86      0.20        51
#
#     accuracy                           0.66      1022
#    macro avg       0.55      0.76      0.49      1022
# weighted avg       0.95      0.66      0.76      1022

# %%
#ajuste de hiperparametros
from sklearn.model_selection import RandomizedSearchCV
import numpy as np

tabela_param = {
    'n_estimators': [100, 200, 300], #numero de arvores
    'max_depth': [10, 20, 30, None], #profundidade max da arvore
    'min_samples_split': [2, 5, 10], #min de exemplos pra dividir um nó
    'min_samples_leaf': [1, 2, 4], #min de exemplos numa folha
    'bootstrap': [True, False] #metodo de amostragem
}

#Randomized Search
rf_ajuste = RandomizedSearchCV(estimator = RandomForestClassifier(class_weight = 'balanced', random_state = 6),
                               param_distributions = tabela_param,
                               n_iter = 50, #50 combinações diferentes
                               cv = 3, #valida cada combinação 3 vezes
                               verbose = 2,
                               random_state = 6,
                               n_jobs = -1, #uso de nucleos
                               scoring = 'recall' #prioriza o recall
                              )

rf_ajuste.fit(x_treino_blc, y_treino_blc) #busca pelos hiperparametros
print(rf_ajuste.best_params_) #printa os melhores

#testa o melhor modelo
melhor_modelo = rf_ajuste.best_estimator_ 
previsoes_otimizadas = melhor_modelo.predict(x_teste)

print("Acurácia:", accuracy_score(y_teste, previsoes_otimizadas))
print(classification_report(y_teste, previsoes_otimizadas))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': 10, 'bootstrap': False}
# Acurácia: 0.8532289628180039
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92       971
#            1       0.18      0.53      0.26        51
#
#     accuracy                           0.85      1022
#    macro avg       0.57      0.70      0.59      1022
# weighted avg       0.93      0.85      0.89      1022

# %%
melhor_modelo = rf_ajuste.best_estimator_
probabilidades = melhor_modelo.predict_proba(x_teste)
chance_avc = probabilidades[:, 1]
limiar = 0.09
previsoes_finais = (chance_avc >= limiar).astype(int)
print("Acurácia:", accuracy_score(y_teste, previsoes_finais))
print(classification_report(y_teste, previsoes_finais))
# Out:
# Acurácia: 0.48336594911937375
#               precision    recall  f1-score   support
#
#            0       0.99      0.46      0.63       971
#            1       0.08      0.94      0.15        51
#
#     accuracy                           0.48      1022
#    macro avg       0.54      0.70      0.39      1022
# weighted avg       0.95      0.48      0.60      1022

# %%
#encontrar o melhor limiar
for i in np.arange(0.05, 0.51, 0.05):
    previsoes_teste = (chance_avc >= i).astype(int)
    acc = accuracy_score(y_teste, previsoes_teste)
    rep = classification_report(y_teste, previsoes_teste, output_dict=True)
    rec_avc = rep['1']['recall']
    prec_avc = rep['1']['precision']

    print(f"{i:.2f}       | {acc:.2f}       | {rec_avc:.2f}            | {prec_avc:.2f}")
# Out:
# 0.05       | 0.41       | 1.00            | 0.08
# 0.10       | 0.51       | 0.94            | 0.09
# 0.15       | 0.58       | 0.88            | 0.10
# 0.20       | 0.64       | 0.82            | 0.11
# 0.25       | 0.68       | 0.78            | 0.11
# 0.30       | 0.73       | 0.75            | 0.12
# 0.35       | 0.76       | 0.67            | 0.13
# 0.40       | 0.79       | 0.63            | 0.14
# 0.45       | 0.82       | 0.57            | 0.15
# 0.50       | 0.85       | 0.53            | 0.18

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.7.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\roniv\anaconda3\lib\site-packages (from optuna) (1.18.0)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in c:\users\roniv\anaconda3\lib\site-packages (from optuna) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\roniv\anaconda3\lib\site-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\roniv\anaconda3\lib\site-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in c:\users\roniv\anaconda3\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in c:\users\roniv\anaconda3\lib\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in c:\users\roniv\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\roniv\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in c:\users\roniv\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: colorama in c:\users\roniv\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\roniv\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.7.0-py3-none-any.whl (413 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
#
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    -------------------- ------------------- 1/2 [optuna]
#    ---------------------------------------- 2/2 [optuna]
#
# Successfully installed colorlog-6.10.1 optuna-4.7.0

# %%
#teste com optuna
import optuna
from sklearn.metrics import f1_score

def objetivo(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500), #num arvores
        'max_depth': trial.suggest_int('max_depth', 5, 30), #profundidade max
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 15), #min de exemplos pra dividir um nó
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10), #min de exemplos numa folha
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'class_weight': 'balanced', # Mantemos fixo para ajudar no desbalanceamento
        'random_state': 6,
        'n_jobs': -1
    }

    #cria e treina modelo
    modelo = RandomForestClassifier(**params)
    modelo.fit(x_treino_blc, y_treino_blc)

    preds = modelo.predict(x_teste) #testa
    return f1_score(y_teste, preds, pos_label=1)

#estudo e otimização
estudo_rf = optuna.create_study(direction = 'maximize')
estudo_rf.optimize(objetivo, n_trials = 100)
print(estudo_rf.best_params)
# Out:
# [I 2026-01-28 14:39:21,287] A new study created in memory with name: no-name-5a017736-3171-47cd-b911-6fcff9834642
# [I 2026-01-28 14:39:22,355] Trial 0 finished with value: 0.22929936305732485 and parameters: {'n_estimators': 311, 'max_depth': 27, 'min_samples_split': 12, 'min_samples_leaf': 4, 'bootstrap': True}. Best is trial 0 with value: 0.22929936305732485.
# [I 2026-01-28 14:39:23,789] Trial 1 finished with value: 0.25316455696202533 and parameters: {'n_estimators': 411, 'max_depth': 14, 'min_samples_split': 15, 'min_samples_leaf': 6, 'bootstrap': False}. Best is trial 1 with value: 0.25316455696202533.
# [I 2026-01-28 14:39:24,715] Trial 2 finished with value: 0.22813688212927757 and parameters: {'n_estimators': 293, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}. Best is trial 1 with value: 0.25316455696202533.
# [I 2026-01-28 14:39:26,316] Trial 3 finished with value: 0.23129251700680273 and parameters: {'n_estimators': 491, 'max_depth': 28, 'min_samples_split': 10, 'min_samples_leaf': 6, 'bootstrap': False}. Best is trial 1 with value: 0.25316455696202533.
# [I 2026-01-28 14:39:27,201] Trial 4 finished with value: 0.234375 and parameters: {'n_estimators': 243, 'max_depth': 16, 'min_samples_split': 14, 'min_samples_leaf': 2, 'bootstrap': False}. Best is trial 1 with value: 0.25316455696202533.
# [I 2026-01-28 14:39:27,740] Trial 5 finished with value: 0.2613065326633166 and parameters: {'n_estimators': 172, 'max_depth': 28, 'min_samples_split': 15, 'min_samples_leaf': 10, 'bootstrap': True}. Best is trial 5 with value: 0.2613065326633166.
# [I 2026-01-28 14:39:28,616] Trial 6 finished with value: 0.22857142857142856 and parameters: {'n_estimators': 214, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 10, 'bootstrap': True}. Best is trial 5 with value: 0.2613065326633166.
# [I 2026-01-28 14:39:29,418] Trial 7 finished with value: 0.26744186046511625 and parameters: {'n_estimators': 241, 'max_depth': 13, 'min_samples_split': 15, 'min_samples_leaf': 7, 'bootstrap': False}. Best is trial 7 with value: 0.26744186046511625.
# [I 2026-01-28 14:39:30,404] Trial 8 finished with value: 0.23357664233576642 and parameters: {'n_estimators': 242, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 2, 'bootstrap': True}. Best is trial 7 with value: 0.26744186046511625.
# [I 2026-01-28 14:39:31,485] Trial 9 finished with value: 0.25842696629213485 and parameters: {'n_estimators': 234, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 6, 'bootstrap': True}. Best is trial 7 with value: 0.26744186046511625.
# [I 2026-01-28 14:39:31,854] Trial 10 finished with value: 0.25380710659898476 and parameters: {'n_estimators': 102, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 8, 'bootstrap': False}. Best is trial 7 with value: 0.26744186046511625.
# [I 2026-01-28 14:39:32,377] Trial 11 finished with value: 0.25287356321839083 and parameters: {'n_estimators': 133, 'max_depth': 22, 'min_samples_split': 15, 'min_samples_leaf': 10, 'bootstrap': False}. Best is trial 7 with value: 0.26744186046511625.
# [I 2026-01-28 14:39:33,197] Trial 12 finished with value: 0.2553191489361702 and parameters: {'n_estimators': 162, 'max_depth': 22, 'min_samples_split': 12, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial
 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:40:51,266] Trial 79 finished with value: 0.2583732057416268 and parameters: {'n_estimators': 301, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 7, 'bootstrap': False}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:40:53,272] Trial 80 finished with value: 0.24509803921568626 and parameters: {'n_estimators': 393, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 7, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:40:54,954] Trial 81 finished with value: 0.2598870056497175 and parameters: {'n_estimators': 387, 'max_depth': 16, 'min_samples_split': 14, 'min_samples_leaf': 6, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:40:56,740] Trial 82 finished with value: 0.26737967914438504 and parameters: {'n_estimators': 359, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 7, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:40:58,475] Trial 83 finished with value: 0.22950819672131148 and parameters: {'n_estimators': 362, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 7, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:40:59,883] Trial 84 finished with value: 0.24870466321243523 and parameters: {'n_estimators': 429, 'max_depth': 15, 'min_samples_split': 14, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:00,868] Trial 85 finished with value: 0.27225130890052357 and parameters: {'n_estimators': 256, 'max_depth': 17, 'min_samples_split': 13, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:01,797] Trial 86 finished with value: 0.25773195876288657 and parameters: {'n_estimators': 256, 'max_depth': 19, 'min_samples_split': 13, 'min_samples_leaf': 9, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:03,120] Trial 87 finished with value: 0.24489795918367346 and parameters: {'n_estimators': 406, 'max_depth': 15, 'min_samples_split': 15, 'min_samples_leaf': 9, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:03,676] Trial 88 finished with value: 0.27225130890052357 and parameters: {'n_estimators': 174, 'max_depth': 17, 'min_samples_split': 14, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:04,416] Trial 89 finished with value: 0.23809523809523808 and parameters: {'n_estimators': 179, 'max_depth': 17, 'min_samples_split': 14, 'min_samples_leaf': 8, 'bootstrap': False}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:05,017] Trial 90 finished with value: 0.25252525252525254 and parameters: {'n_estimators': 171, 'max_depth': 21, 'min_samples_split': 13, 'min_samples_leaf': 9, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:05,733] Trial 91 finished with value: 0.25668449197860965 and parameters: {'n_estimators': 194, 'max_depth': 16, 'min_samples_split': 15, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:06,226] Trial 92 finished with value: 0.25396825396825395 and parameters: {'n_estimators': 152, 'max_depth': 17, 'min_samples_split': 14, 'min_samples_leaf': 7, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:07,023] Trial 93 finished with value: 0.2553191489361702 and parameters: {'n_estimators': 227, 'max_depth': 18, 'min_samples_split': 15, 'min_samples_leaf': 7, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:07,888] Trial 94 finished with value: 0.24731182795698925 and parameters: {'n_estimators': 235, 'max_depth': 16, 'min_samples_split': 14, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:09,175] Trial 95 finished with value: 0.2631578947368421 and parameters: {'n_estimators': 276, 'max_depth': 19, 'min_samples_split': 13, 'min_samples_leaf': 8, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:09,821] Trial 96 finished with value: 0.26737967914438504 and parameters: {'n_estimators': 189, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 7, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:10,737] Trial 97 finished with value: 0.2621359223300971 and parameters: {'n_estimators': 248, 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 9, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:13,416] Trial 98 finished with value: 0.24870466321243523 and parameters: {'n_estimators': 445, 'max_depth': 14, 'min_samples_split': 15, 'min_samples_leaf': 7, 'bootstrap': True}. Best is trial 34 with value: 0.2736842105263158.
# [I 2026-01-28 14:41:14,154] Trial 99 finished with value: 0.2289156626506024 and parameters: {'n_estimators': 218, 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 6, 'bootstrap': False}. Best is trial 34 with value: 0.2736842105263158.
# {'n_estimators': 455, 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 6, 'bootstrap': True}

# %%
from sklearn.metrics import classification_report

melhores_params = estudo_rf.best_params
melhores_params['class_weight'] = 'balanced'
melhores_params['random_state'] = 6
melhores_params['n_jobs'] = -1

#treino
modelo_final_rf = RandomForestClassifier(**melhores_params)
modelo_final_rf.fit(x_treino_blc, y_treino_blc)

limiar_final = 0.20 
probabilidades = modelo_final_rf.predict_proba(x_teste)[:, 1]
previsoes_finais = (probabilidades >= limiar_final).astype(int)

print("Acurácia:", accuracy_score(y_teste, previsoes_finais))
print(classification_report(y_teste, previsoes_finais))
# Out:
# Acurácia: 0.6575342465753424
#               precision    recall  f1-score   support
#
#            0       0.99      0.65      0.78       971
#            1       0.11      0.86      0.20        51
#
#     accuracy                           0.66      1022
#    macro avg       0.55      0.75      0.49      1022
# weighted avg       0.95      0.66      0.75      1022
